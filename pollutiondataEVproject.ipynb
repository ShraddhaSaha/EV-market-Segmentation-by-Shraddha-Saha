# %%
#import necessary libraries:
import numpy as np
import pandas as pd

# %%
import seaborn as sns                   
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Ignore any warnings 
import warnings  
warnings.filterwarnings("ignore")

# %%
#reading the data:
pollutiondataEV=pd.read_csv("pollutiondataEVproject.csv")

# %%
pollutiondataEV
# Out:
#                      state    status  AQI-US  PM2.5  PM10  Temp  Humid
# 0           Andhra Pradesh  MODERATE      56     16    31    28     74
# 1        Arunachal Pradesh      GOOD      39     11    17    21    100
# 2                    Assam      GOOD      46     13    20    23     98
# 3                    Bihar  MODERATE      87     28    53    31     58
# 4               Chandigarh      POOR     107     38    49    25     53
# 5             Chhattisgarh  MODERATE      67     20    46    27     72
# 6   Dadra And Nagar Haveli  MODERATE      62     16    35    27     82
# 7            Daman And Diu  MODERATE      61     16    33    28     79
# 8                    Delhi      POOR     108     37   113    29     58
# 9                      Goa      GOOD      30      8    20    27     81
# 10                 Gujarat  MODERATE      68     20    42    30     68
# 11                 Haryana  MODERATE     100     35    73    28     64
# ...

# %%
pollutiondataEV.shape
# Out:
# (34, 7)

# %%
pollutiondataEV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   34 non-null     object
#  1   status  34 non-null     object
#  2   AQI-US  34 non-null     int64
#  3   PM2.5   34 non-null     int64
#  4   PM10    34 non-null     int64
#  5   Temp    34 non-null     int64
#  6   Humid   34 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 2.0+ KB

# %%
pollutiondataEV.describe()
# Out:
#            AQI-US      PM2.5        PM10       Temp       Humid
# count   34.000000  34.000000   34.000000  34.000000   34.000000
# mean    64.382353  19.382353   41.058824  24.676471   77.911765
# std     25.817559  10.048412   22.571021   4.623527   14.321773
# min     14.000000   2.000000    5.000000  13.000000   53.000000
# 25%     54.250000  14.250000   29.500000  21.500000   67.250000
# 50%     63.000000  18.000000   40.500000  27.000000   78.000000
# 75%     77.500000  22.000000   51.750000  28.000000   86.750000
# max    108.000000  38.000000  113.000000  31.000000  100.000000

# %%
pollutiondataEV.isnull().sum()
# Out:
# state     0
# status    0
# AQI-US    0
# PM2.5     0
# PM10      0
# Temp      0
# Humid     0
# dtype: int64

# %%
sns.pairplot(pollutiondataEV)

# %%
# Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(pollutiondataEV.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#barplot:
plt.figure(figsize=(10,7))
sns.barplot(x="Temp",y="state",data=pollutiondataEV,color="yellow")
# Out:
# <Axes: xlabel='Temp', ylabel='state'>

# %%
plt.figure(figsize=(34,8));
sns.swarmplot(x="state", y="status", data=pollutiondataEV)
# Out:
# <Axes: xlabel='state', ylabel='status'>

# %%
plt.figure(figsize=(20,20));
sns.jointplot(x='state', y='status', data=pollutiondataEV, kind='scatter',space=0.5);

# %%
# Distribution of status
plt.figure(figsize=(10, 6))
sns.countplot(x='status', data=pollutiondataEV)
plt.title('Distribution of Status')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()
